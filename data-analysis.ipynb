# %% [markdown]
# # Figuring out the data

# %% [markdown]
# Set up Pandas

# %%
import pandas as pd
pd.options.display.max_columns = None
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ## Key

# %%
key = pd.read_csv("signdataKEY.csv",encoding='ISO-8859-1')
key
# Out:
#                        VariableName(CSV&OSF)  \
# 0                                    EntryID
# 1                                    LemmaID
# 2                                       Code
# 3                                      Batch
# 4                                       List
# 5                                       Item
# 6                            EnglishWF(lg10)
# 7                           SignFrequency(M)
# 8                          SignFrequency(SD)
# 9                           SignFrequency(Z)
# 10                          SignFrequency(N)
# 11                                   Unknown
# 12                   SignFrequency(M-Native)
# 13                  SignFrequency(SD-Native)
# 14                        SignFreq(Z-native)
# 15                   SignFrequency(N-Native)
# 16                           Unknown(Native)
# 17                SignFrequency(M-Nonnative)
# 18               SignFrequency(SD-Nonnative)
# 19                SignFrequency(N-Nonnative)
# 20                     SignFreq(Z-Nonnative)
# 21                        Unknown(Nonnative)
# 22                       DominantTranslation
# 23              DominantTranslationAgreement
# 24      DominantTranslationAgreement(Native)
# 25   DominantTranslationAgreement(Nonnative)
# 26                   NondominantTranslations
# 27                              Iconicity(M)
# 28                             Iconicity(SD)
# 29                              Iconicity(Z)
# 30                              Iconicity(N)
# 31                              Iconicity_ID
# 32                            D.Iconicity(M)
# 33                           D.Iconicity(SD)
# 34                            D.Iconicity(N)
# 35                            D.Iconicity(Z)
# 36                     D.Iconicity(M-native)
# 37                    D.Iconicity(SD-native)
# 38                     D.Iconicity(Z-native)
# 39                     D.Iconicity(N-native)
# 40                          GuessConsistency
# 41                             GuessAccuracy
# 42                           Transparency(M)
# 43                           Transparency SD
# 44                            Transparency Z
# 45                              LexicalClass
# 46                           Initialized.2.0
# 47                 FingerspelledLoanSign.2.0
# 48                              Compound.2.0
# 49                     NumberOfMorphemes.2.0
# 50                             SignOnset(ms)
# 51                            SignOffset(ms)
# 52                          SignDuration(ms)
# 53                          ClipDuration(ms)
# 54                             Handshape.2.0
# 55                       SelectedFingers.2.0
# 56                               Flexion.2.0
# 57                         FlexionChange.2.0
# 58                                Spread.2.0
# 59                          SpreadChange.2.0
# 60                         ThumbPosition.2.0
# 61                          ThumbContact.2.0
# 62                              SignType.2.0
# 63                              Movement.2.0
# 64                      RepeatedMovement.2.0
# 65                         MajorLocation.2.0
# 66                         MinorLocation.2.0
# 67                   SecondMinorLocation.2.0
# 68                               Contact.2.0
# 69                  NonDominantHandshape.2.0
# 70                         UlnarRotation.2.0
# 71                           HandshapeM2.2.0
# 72                     SelectedFingersM2.2.0
# 73                             FlexionM2.2.0
# 74                       FlexionChangeM2.2.0
# 75                              SpreadM2.2.0
# 76                        SpreadChangeM2.2.0
# 77                       ThumbPositionM2.2.0
# 78                        ThumbContactM2.2.0
# 79                            SignTypeM2.2.0
# 80                            MovementM2.2.0
# 81                    RepeatedMovementM2.2.0
# 82                       MajorLocationM2.2.0
# 83                       MinorLocationM2.2.0
# 84                 SecondMinorLocationM2.2.0
# 85                             ContactM2.2.0
# 86                NonDominantHandshapeM2.2.0
# 87                       UlnarRotationM2.2.0
# 88                           HandshapeM3.2.0
# 89                     SelectedFingersM3.2.0
# 90                             FlexionM3.2.0
# 91                       FlexionChangeM3.2.0
# 92                              SpreadM3.2.0
# 93                        SpreadChangeM3.2.0
# 94                       ThumbPositionM3.2.0
# 95                        ThumbContactM3.2.0
# 96                            SignTypeM3.2.0
# 97                            MovementM3.2.0
# 98                    RepeatedMovementM3.2.0
# 99                       MajorLocationM3.2.0
# 100                      MinorLocationM3.2.0
# 101                SecondMinorLocationM3.2.0
# 102                            ContactM3.2.0
# 103               NonDominantHandshapeM3.2.0
# 104                      UlnarRotationM3.2.0
# 105                          HandshapeM4.2.0
# 106                    SelectedFingersM4.2.0
# 107                            FlexionM4.2.0
# 108                      FlexionChangeM4.2.0
# 109                             SpreadM4.2.0
# 110                       SpreadChangeM4.2.0
# 111                      ThumbPositionM4.2.0
# 112                       ThumbContactM4.2.0
# 113                           SignTypeM4.2.0
# 114                           MovementM4.2.0
# 115                   RepeatedMovementM4.2.0
# 116                      MajorLocationM4.2.0
# 117                      MinorLocationM4.2.0
# 118                SecondMinorLocationM4.2.0
# 119                            ContactM4.2.0
# 120               NonDominantHandshapeM4.2.0
# 121                      UlnarRotationM4.2.0
# 122                          HandshapeM5.2.0
# 123                    SelectedFingersM5.2.0
# 124                            FlexionM5.2.0
# 125                      FlexionChangeM5.2.0
# 126                             SpreadM5.2.0
# 127                       SpreadChangeM5.2.0
# 128                      ThumbPositionM5.2.0
# 129                       ThumbContactM5.2.0
# 130                           SignTypeM5.2.0
# 131                           MovementM5.2.0
# 132                   RepeatedMovementM5.2.0
# 133                      MajorLocationM5.2.0
# 134                      MinorLocationM5.2.0
# 135                SecondMinorLocationM5.2.0
# 136                            ContactM5.2.0
# 137               NonDominantHandshapeM5.2.0
# 138                      UlnarRotationM5.2.0
# 139                          HandshapeM6.2.0
# 140                    SelectedFingersM6.2.0
# 141                            FlexionM6.2.0
# 142                      FlexionChangeM6.2.0
# 143                             SpreadM6.2.0
# 144                       SpreadChangeM6.2.0
# 145                      ThumbPositionM6.2.0
# 146                       ThumbContactM6.2.0
# 147                           SignTypeM6.2.0
# 148                           MovementM6.2.0
# 149                   RepeatedMovementM6.2.0
# 150                      MajorLocationM6.2.0
# 151                      MinorLocationM6.2.0
# 152                SecondMinorLocationM6.2.0
# 153                            ContactM6.2.0
# 154               NonDominantHandshapeM6.2.0
# 155                      UlnarRotationM6.2.0
# 156                    SignType.2.0Frequency
# 157               MajorLocation.2.0Frequency
# 158               MinorLocation.2.0Frequency
# 159         SecondMinorLocation.2.0Frequency
# 160                    Movement.2.0Frequency
# 161             SelectedFingers.2.0Frequency
# 162                     Flexion.2.0Frequency
# 163               FlexionChange.2.0Frequency
# 164            RepeatedMovement.2.0Frequency
# 165                     Contact.2.0Frequency
# 166                      Spread.2.0Frequency
# 167                SpreadChange.2.0Frequency
# 168                ThumbContact.2.0Frequency
# 169               ThumbPosition.2.0Frequency
# 170               UlnarRotation.2.0Frequency
# 171                 Neighborhood Density 2.0
# 172       Parameter.Neighborhood.Density.2.0
# 173                   PhonotacticProbability
# 174                  Phonological Complexity
# 175                     SignBankAnnotationID
# 176              SignBankEnglishTranslations
# 177                          SignBankLemmaID
# 178                    SignBankSemanticField
# 179                      SignBankReferenceID
# 180                                    InCDI
# 181                      CDISemanticCategory
# 182                                 bglm_aoa
# 183                            empirical_aoa
#
#                                  Website variable name  \
# 0                                             Entry ID
# 1                                             Lemma ID
# 2                                        Code (survey)
# 3                                        Code (survey)
# 4                                        Code (survey)
# 5                                        Code (survey)
# 6                               English Word Frequency
# 7                                            Frequency
# 8                                         Frequency SD
# 9                                          Frequency Z
# 10                                         Frequency N
# 11                                        Sign Unknown
# 12                                  Frequency (Native)
# 13                              Frequency SD (Native)
# 14                               Frequency Z (Native)
# 15                               Frequency N (Native)
# 16                  Sign Unknown (Native) (proportion)
# 17                               Frequency (Nonnative)
# 18                            Frequency SD (Nonnative)
# 19                             Frequency Z (Nonnative)
# 20                             Frequency N (Nonnative)
# 21               Sign Unknown (Nonnative) (proportion)
# 22                                Dominant Translation
# 23         Dominant Translation Agreement (proportion)
# 24   Dominant Translation Agreement (Native) (propo...
# 25   Dominant Translation Agreement (Nonnative) (pr...
# 26                            Nondominant Translations
# 27                                Non-Signer Iconicity
# 28                             Non-Signer Iconicity SD
# 29                              Non-Signer Iconicity Z
# 30                              Non-Signer Iconicity N
# 31                             Non-Signer Iconicity ID
# 32                               Deaf Signer Iconicity
# 33                            Deaf Signer Iconicity SD
# 34                             Deaf Signer Iconicity Z
# 35                             Deaf Signer Iconicity N
# 36                      Deaf Signer Iconicity (Native)
# 37                   Deaf Signer Iconicity SD (Native)
# 38                    Deaf Signer Iconicity Z (Native)
# 39                    Deaf Signer Iconicity N (Native)
# 40                              Consistency of Guesses
# 41                    Accuracy of Guesses (proportion)
# 42                                        Transparency
# 43                                     Transparency SD
# 44                                      Transparency Z
# 45                                       Lexical Class
# 46                                    Initialized Sign
# 47                             Fingerspelled Loan Sign
# 48                                            Compound
# 49                                 Number Of Morphemes
# 50                                          Sign Onset
# 51                                         Sign Offset
# 52                                       Sign Duration
# 53                                      Video Duration
# 54                                           Handshape
# 55                                    Selected Fingers
# 56                                             Flexion
# 57                                      Flexion Change
# 58                                              Spread
# 59                                       Spread Change
# 60                                      Thumb Position
# 61                                       Thumb Contact
# 62                                           Sign Type
# 63                                       Path Movement
# 64                                   Repeated Movement
# 65                                      Major Location
# 66                                      Minor Location
# 67                               Second Minor Location
# 68                                             Contact
# 69                               Nondominant Handshape
# 70                                         Wrist Twist
# 71                                Handshape Morpheme 2
# 72                         Selected Fingers Morpheme 2
# 73                                  Flexion Morpheme 2
# 74                           Flexion Change Morpheme 2
# 75                                   Spread Morpheme 2
# 76                            Spread Change Morpheme 2
# 77                           Thumb Position Morpheme 2
# 78                            Thumb Contact Morpheme 2
# 79                                Sign Type Morpheme 2
# 80                                 Movement Morpheme 2
# 81                        Repeated Movement Morpheme 2
# 82                           Major Location Morpheme 2
# 83                           Minor Location Morpheme 2
# 84                    Second Minor Location Morpheme 2
# 85                                  Contact Morpheme 2
# 86                    Nondominant Handshape Morpheme 2
# 87                              Wrist Twist Morpheme 2
# 88                                Handshape Morpheme 3
# 89                         Selected Fingers Morpheme 3
# 90                                  Flexion Morpheme 3
# 91                           Flexion Change Morpheme 3
# 92                                   Spread Morpheme 3
# 93                            Spread Change Morpheme 3
# 94                           Thumb Position Morpheme 3
# 95                            Thumb Contact Morpheme 3
# 96                                 Signtype Morpheme 3
# 97                                 Movement Morpheme 3
# 98                        Repeated Movement Morpheme 3
# 99                           Major Location Morpheme 3
# 100                          Minor Location Morpheme 3
# 101                   Second Minor Location Morpheme 3
# 102                                 Contact Morpheme 3
# 103                   Nondominant Handshape Morpheme 3
# 104                             Wrist Twist Morpheme 3
# 105                               Handshape Morpheme 4
# 106                        Selected Fingers Morpheme 4
# 107                                 Flexion Morpheme 4
# 108                          Flexion Change Morpheme 4
# 109                                  Spread Morpheme 4
# 110                           Spread Change Morpheme 4
# 111                          Thumb Position Morpheme 4
# 112                           Thumb Contact Morpheme 4
# 113                               Sign Type Morpheme 4
# 114                                Movement Morpheme 4
# 115                       Repeated Movement Morpheme 4
# 116                          Major Location Morpheme 4
# 117                          Minor Location Morpheme 4
# 118                   Second Minor Location Morpheme 4
# 119                                 Contact Morpheme 4
# 120                   Nondominant Handshape Morpheme 4
# 121                             Wrist Twist Morpheme 4
# 122                               Handshape Morpheme 5
# 123                        Selected Fingers Morpheme 5
# 124                                 Flexion Morpheme 5
# 125                          Flexion Change Morpheme 5
# 126                                  Spread Morpheme 5
# 127                           Spread Change Morpheme 5
# 128                          Thumb Position Morpheme 5
# 129                           Thumb Contact Morpheme 5
# 130                               Sign Type Morpheme 5
# 131                                Movement Morpheme 5
# 132                       Repeated Movement Morpheme 5
# 133                          Major Location Morpheme 5
# 134                          Minor Location Morpheme 5
# 135                   Second Minor Location Morpheme 5
# 136                                 Contact Morpheme 5
# 137                   Nondominant Handshape Morpheme 5
# 138                             Wrist Twist Morpheme 5
# 139                               Handshape Morpheme 6
# 140                        Selected Fingers Morpheme 6
# 141                                 Flexion Morpheme 6
# 142                          Flexion Change Morpheme 6
# 143                                  Spread Morpheme 6
# 144                           Spread Change Morpheme 6
# 145                          Thumb Position Morpheme 6
# 146                           Thumb Contact Morpheme 6
# 147                               Sign Type Morpheme 6
# 148                                Movement Morpheme 6
# 149                       Repeated Movement Morpheme 6
# 150                          Major Location Morpheme 6
# 151                          Minor Location Morpheme 6
# 152                   Second Minor Location Morpheme 6
# 153                                 Contact Morpheme 6
# 154                   Nondominant Handshape Morpheme 6
# 155                             Wrist Twist Morpheme 6
# 156                                Sign Type Frequency
# 157                           Major Location Frequency
# 158                           Minor Location Frequency
# 159                    Second Minor Location Frequency
# 160                                 Movement Frequency
# 161                         Selected Fingers Frequency
# 162                                  Flexion Frequency
# 163                           Flexion Change Frequency
# 164                        Repeated Movement Frequency
# 165                                  Contact Frequency
# 166                                   Spread Frequency
# 167                            Spread Change Frequency
# 168                            Thumb Contact Frequency
# 169                           Thumb Position Frequency
# 170                           Ulnar Rotation Frequency
# 171                               Neighborhood Density
# 172                     Parameter Neighborhood Density
# 173                            Phonotactic Probability
# 174                            Phonological Complexity
# 175                             SignBank Annotation ID
# 176                      SignBank English Translations
# 177                                  SignBank Lemma ID
# 178                            SignBank Semantic Field
# 179                              SignBank Reference ID
# 180                                             In CDI
# 181                              CDI Semantic Category
# 182                                 Age Of Acquisition
# 183                     Age Of Acquisition (Empirical)
#
#             Sign Data and Filter Group  \
# 0                  English Translation
# 1                  English Translation
# 2                                 Code
# 3                                 Code
# 4                                 Code
# 5                                 Code
# 6                            Frequency
# 7                            Frequency
# 8                            Frequency
# 9                            Frequency
# 10                           Frequency
# 11                           Frequency
# 12                           Frequency
# 13                           Frequency
# 14                           Frequency
# 15                           Frequency
# 16                           Frequency
# 17                           Frequency
# 18                           Frequency
# 19                           Frequency
# 20                           Frequency
# 21                           Frequency
# 22                           Frequency
# 23                           Frequency
# 24                           Frequency
# 25                           Frequency
# 26                           Frequency
# 27                           Iconicity
# 28                           Iconicity
# 29                           Iconicity
# 30                           Iconicity
# 31                           Iconicity
# 32                           Iconicity
# 33                           Iconicity
# 34                           Iconicity
# 35                           Iconicity
# 36                           Iconicity
# 37                           Iconicity
# 38                           Iconicity
# 39                           Iconicity
# 40                           Iconicity
# 41                           Iconicity
# 42                           Iconicity
# 43                           Iconicity
# 44                           Iconicity
# 45                  Lexical Properties
# 46                  Lexical Properties
# 47                  Lexical Properties
# 48                  Lexical Properties
# 49                  Lexical Properties
# 50                       Sign Duration
# 51                       Sign Duration
# 52                       Sign Duration
# 53                       Sign Duration
# 54                           Phonology
# 55                           Phonology
# 56                           Phonology
# 57                           Phonology
# 58                           Phonology
# 59                           Phonology
# 60                           Phonology
# 61                           Phonology
# 62                           Phonology
# 63                           Phonology
# 64                           Phonology
# 65                           Phonology
# 66                           Phonology
# 67                           Phonology
# 68                           Phonology
# 69                           Phonology
# 70                           Phonology
# 71   Phonology of Additional Morphemes
# 72   Phonology of Additional Morphemes
# 73   Phonology of Additional Morphemes
# 74   Phonology of Additional Morphemes
# 75   Phonology of Additional Morphemes
# 76   Phonology of Additional Morphemes
# 77   Phonology of Additional Morphemes
# 78   Phonology of Additional Morphemes
# 79   Phonology of Additional Morphemes
# 80   Phonology of Additional Morphemes
# 81   Phonology of Additional Morphemes
# 82   Phonology of Additional Morphemes
# 83   Phonology of Additional Morphemes
# 84   Phonology of Additional Morphemes
# 85   Phonology of Additional Morphemes
# 86   Phonology of Additional Morphemes
# 87   Phonology of Additional Morphemes
# 88   Phonology of Additional Morphemes
# 89   Phonology of Additional Morphemes
# 90   Phonology of Additional Morphemes
# 91   Phonology of Additional Morphemes
# 92   Phonology of Additional Morphemes
# 93   Phonology of Additional Morphemes
# 94   Phonology of Additional Morphemes
# 95   Phonology of Additional Morphemes
# 96   Phonology of Additional Morphemes
# 97   Phonology of Additional Morphemes
# 98   Phonology of Additional Morphemes
# 99   Phonology of Additional Morphemes
# 100  Phonology of Additional Morphemes
# 101  Phonology of Additional Morphemes
# 102  Phonology of Additional Morphemes
# 103  Phonology of Additional Morphemes
# 104  Phonology of Additional Morphemes
# 105  Phonology of Additional Morphemes
# 106  Phonology of Additional Morphemes
# 107  Phonology of Additional Morphemes
# 108  Phonology of Additional Morphemes
# 109  Phonology of Additional Morphemes
# 110  Phonology of Additional Morphemes
# 111  Phonology of Additional Morphemes
# 112  Phonology of Additional Morphemes
# 113  Phonology of Additional Morphemes
# 114  Phonology of Additional Morphemes
# 115  Phonology of Additional Morphemes
# 116  Phonology of Additional Morphemes
# 117  Phonology of Additional Morphemes
# 118  Phonology of Additional Morphemes
# 119  Phonology of Additional Morphemes
# 120  Phonology of Additional Morphemes
# 121  Phonology of Additional Morphemes
# 122  Phonology of Additional Morphemes
# 123  Phonology of Additional Morphemes
# 124  Phonology of Additional Morphemes
# 125  Phonology of Additional Morphemes
# 126  Phonology of Additional Morphemes
# 127  Phonology of Additional Morphemes
# 128  Phonology of Additional Morphemes
# 129  Phonology of Additional Morphemes
# 130  Phonology of Additional Morphemes
# 131  Phonology of Additional Morphemes
# 132  Phonology of Additional Morphemes
# 133  Phonology of Additional Morphemes
# 134  Phonology of Additional Morphemes
# 135  Phonology of Additional Morphemes
# 136  Phonology of Additional Morphemes
# 137  Phonology of Additional Morphemes
# 138  Phonology of Additional Morphemes
# 139  Phonology of Additional Morphemes
# 140  Phonology of Additional Morphemes
# 141  Phonology of Additional Morphemes
# 142  Phonology of Additional Morphemes
# 143  Phonology of Additional Morphemes
# 144  Phonology of Additional Morphemes
# 145  Phonology of Additional Morphemes
# 146  Phonology of Additional Morphemes
# 147  Phonology of Additional Morphemes
# 148  Phonology of Additional Morphemes
# 149  Phonology of Additional Morphemes
# 150  Phonology of Additional Morphemes
# 151  Phonology of Additional Morphemes
# 152  Phonology of Additional Morphemes
# 153  Phonology of Additional Morphemes
# 154  Phonology of Additional Morphemes
# 155  Phonology of Additional Morphemes
# 156               Sublexical Frequency
# 157               Sublexical Frequency
# 158               Sublexical Frequency
# 159               Sublexical Frequency
# 160               Sublexical Frequency
# 161               Sublexical Frequency
# 162               Sublexical Frequency
# 163               Sublexical Frequency
# 164               Sublexical Frequency
# 165               Sublexical Frequency
# 166               Sublexical Frequency
# 167               Sublexical Frequency
# 168               Sublexical Frequency
# 169               Sublexical Frequency
# 170               Sublexical Frequency
# 171          Phonological Calculations
# 172          Phonological Calculations
# 173          Phonological Calculations
# 174          Phonological Calculations
# 175                           SignBank
# 176                           SignBank
# 177                           SignBank
# 178                           SignBank
# 179                           SignBank
# 180                        Acquisition
# 181                        Acquisition
# 182            Acquisition Information
# 183            Acquisition Information
#
#                     Filter menu outer description info  \
# 0                         Sign identifying information
# 1                         Sign identifying information
# 2                         Sign identifying information
# 3                         Sign identifying information
# 4                         Sign identifying information
# 5                         Sign identifying information
# 6    The frequency of the sign and/or its English t...
# 7    The frequency of the sign and/or its English t...
# 8    The frequency of the sign and/or its English t...
# 9    The frequency of the sign and/or its English t...
# 10   The frequency of the sign and/or its English t...
# 11   The frequency of the sign and/or its English t...
# 12   The frequency of the sign and/or its English t...
# 13   The frequency of the sign and/or its English t...
# 14   The frequency of the sign and/or its English t...
# 15   The frequency of the sign and/or its English t...
# 16   The frequency of the sign and/or its English t...
# 17   The frequency of the sign and/or its English t...
# 18   The frequency of the sign and/or its English t...
# 19   The frequency of the sign and/or its English t...
# 20   The frequency of the sign and/or its English t...
# 21   The frequency of the sign and/or its English t...
# 22   The frequency of the sign and/or its English t...
# 23   The frequency of the sign and/or its English t...
# 24   The frequency of the sign and/or its English t...
# 25   The frequency of the sign and/or its English t...
# 26   The frequency of the sign and/or its English t...
# 27   The relationship between the sign form and its...
# 28   The relationship between the sign form and its...
# 29   The relationship between the sign form and its...
# 30   The relationship between the sign form and its...
# 31   The relationship between the sign form and its...
# 32   The relationship between the sign form and its...
# 33   The relationship between the sign form and its...
# 34   The relationship between the sign form and its...
# 35   The relationship between the sign form and its...
# 36   The relationship between the sign form and its...
# 37   The relationship between the sign form and its...
# 38   The relationship between the sign form and its...
# 39   The relationship between the sign form and its...
# 40   The relationship between the sign form and its...
# 41   The relationship between the sign form and its...
# 42   The relationship between the sign form and its...
# 43   The relationship between the sign form and its...
# 44   The relationship between the sign form and its...
# 45                             Lexical characteristics
# 46                             Lexical characteristics
# 47                             Lexical characteristics
# 48                             Lexical characteristics
# 49                             Lexical characteristics
# 50                  Length of the sign in milliseconds
# 51                  Length of the sign in milliseconds
# 52                  Length of the sign in milliseconds
# 53                  Length of the sign in milliseconds
# 54   The phonological composition of the initial "m...
# 55   The phonological composition of the initial "m...
# 56   The phonological composition of the initial "m...
# 57   The phonological composition of the initial "m...
# 58   The phonological composition of the initial "m...
# 59   The phonological composition of the initial "m...
# 60   The phonological composition of the initial "m...
# 61   The phonological composition of the initial "m...
# 62   The phonological composition of the initial "m...
# 63   The phonological composition of the initial "m...
# 64   The phonological composition of the initial "m...
# 65   The phonological composition of the initial "m...
# 66   The phonological composition of the initial "m...
# 67   The phonological composition of the initial "m...
# 68   The phonological composition of the initial "m...
# 69   The phonological composition of the initial "m...
# 70   The phonological composition of the initial "m...
# 71   The phonological composition of subsequent seq...
# 72   The phonological composition of subsequent seq...
# 73   The phonological composition of subsequent seq...
# 74   The phonological composition of subsequent seq...
# 75   The phonological composition of subsequent seq...
# 76   The phonological composition of subsequent seq...
# 77   The phonological composition of subsequent seq...
# 78   The phonological composition of subsequent seq...
# 79   The phonological composition of subsequent seq...
# 80   The phonological composition of subsequent seq...
# 81   The phonological composition of subsequent seq...
# 82   The phonological composition of subsequent seq...
# 83   The phonological composition of subsequent seq...
# 84   The phonological composition of subsequent seq...
# 85   The phonological composition of subsequent seq...
# 86   The phonological composition of subsequent seq...
# 87   The phonological composition of subsequent seq...
# 88   The phonological composition of subsequent seq...
# 89   The phonological composition of subsequent seq...
# 90   The phonological composition of subsequent seq...
# 91   The phonological composition of subsequent seq...
# 92   The phonological composition of subsequent seq...
# 93   The phonological composition of subsequent seq...
# 94   The phonological composition of subsequent seq...
# 95   The phonological composition of subsequent seq...
# 96   The phonological composition of subsequent seq...
# 97   The phonological composition of subsequent seq...
# 98   The phonological composition of subsequent seq...
# 99   The phonological composition of subsequent seq...
# 100  The phonological composition of subsequent seq...
# 101  The phonological composition of subsequent seq...
# 102  The phonological composition of subsequent seq...
# 103  The phonological composition of subsequent seq...
# 104  The phonological composition of subsequent seq...
# 105  The phonological composition of subsequent seq...
# 106  The phonological composition of subsequent seq...
# 107  The phonological composition of subsequent seq...
# 108  The phonological composition of subsequent seq...
# 109  The phonological composition of subsequent seq...
# 110  The phonological composition of subsequent seq...
# 111  The phonological composition of subsequent seq...
# 112  The phonological composition of subsequent seq...
# 113  The phonological composition of subsequent seq...
# 114  The phonological composition of subsequent seq...
# 115  The phonological composition of subsequent seq...
# 116  The phonological composition of subsequent seq...
# 117  The phonological composition of subsequent seq...
# 118  The phonological composition of subsequent seq...
# 119  The phonological composition of subsequent seq...
# 120  The phonological composition of subsequent seq...
# 121  The phonological composition of subsequent seq...
# 122  The phonological composition of subsequent seq...
# 123  The phonological composition of subsequent seq...
# 124  The phonological composition of subsequent seq...
# 125  The phonological composition of subsequent seq...
# 126  The phonological composition of subsequent seq...
# 127  The phonological composition of subsequent seq...
# 128  The phonological composition of subsequent seq...
# 129  The phonological composition of subsequent seq...
# 130  The phonological composition of subsequent seq...
# 131  The phonological composition of subsequent seq...
# 132  The phonological composition of subsequent seq...
# 133  The phonological composition of subsequent seq...
# 134  The phonological composition of subsequent seq...
# 135  The phonological composition of subsequent seq...
# 136  The phonological composition of subsequent seq...
# 137  The phonological composition of subsequent seq...
# 138  The phonological composition of subsequent seq...
# 139  The phonological composition of subsequent seq...
# 140  The phonological composition of subsequent seq...
# 141  The phonological composition of subsequent seq...
# 142  The phonological composition of subsequent seq...
# 143  The phonological composition of subsequent seq...
# 144  The phonological composition of subsequent seq...
# 145  The phonological composition of subsequent seq...
# 146  The phonological composition of subsequent seq...
# 147  The phonological composition of subsequent seq...
# 148  The phonological composition of subsequent seq...
# 149  The phonological composition of subsequent seq...
# 150  The phonological composition of subsequent seq...
# 151  The phonological composition of subsequent seq...
# 152  The phonological composition of subsequent seq...
# 153  The phonological composition of subsequent seq...
# 154  The phonological composition of subsequent seq...
# 155  The phonological composition of subsequent seq...
# 156  The frequency of the value of a phonological f...
# 157  The frequency of the value of a phonological f...
# 158  The frequency of the value of a phonological f...
# 159  The frequency of the value of a phonological f...
# 160  The frequency of the value of a phonological f...
# 161  The frequency of the value of a phonological f...
# 162  The frequency of the value of a phonological f...
# 163  The frequency of the value of a phonological f...
# 164  The frequency of the value of a phonological f...
# 165  The frequency of the value of a phonological f...
# 166  The frequency of the value of a phonological f...
# 167  The frequency of the value of a phonological f...
# 168  The frequency of the value of a phonological f...
# 169  The frequency of the value of a phonological f...
# 170  The frequency of the value of a phonological f...
# 171  A set of phonological calculations based on th...
# 172  A set of phonological calculations based on th...
# 173  A set of phonological calculations based on th...
# 174  A set of phonological calculations based on th...
# 175  Information from the ASL SignBank. Julie A. Ho...
# 176  Information from the ASL SignBank. Julie A. Ho...
# 177  Information from the ASL SignBank. Julie A. Ho...
# 178  Information from the ASL SignBank. Julie A. Ho...
# 179  Information from the ASL SignBank. Julie A. Ho...
# 180  When the sign is acquired (see Caselli, Lieber...
# 181  When the sign is acquired (see Caselli, Lieber...
# 182  When the sign is acquired (see Caselli, Lieber...
# 183  When the sign is acquired (see Caselli, Lieber...
#
#                                     VariableDefinition  \
# 0    An English word that uniquely identifies each ...
# 1    An English word that uniquely identifies each ...
# 2    A code that uniquely identifies each video in ...
# 3    A code that uniquely identifies each video in ...
# 4    A code that uniquely identifies each video in ...
# 5    A code that uniquely identifies each video in ...
# 6    English based word frequency retrieved from Su...
# 7    Mean subjective frequency rating for all deaf ...
# 8    Mean subjective frequency rating standard devi...
# 9    Mean standardized subjective frequency rating ...
# 10   Number of deaf ASL signers on which Sign Frequ...
# 11   Proportion of deaf signing participants who di...
# 12   Mean subjective frequency rating for deaf nati...
# 13   Mean subjective frequency rating standard devi...
# 14   Mean standardized subjective frequency rating ...
# 15   Number of participants on which Sign Frequency...
# 16   Percentage of participants who did not know th...
# 17   Mean subjective frequency rating for deaf non-...
# 18   Mean subjective frequency rating standard devi...
# 19   Mean standardized subjective frequency rating ...
# 20   Number of participants on which Sign Frequency...
# 21   Percentage of participants who did not know th...
# 22   The most common dominant English translation p...
# 23   Proportion agreement with the dominant English...
# 24   Proportion agreement with the dominant English...
# 25   Proportion agreement with the dominant English...
# 26   The other English words provided by the signer...
# 27   Mean iconicity rating from hearing non-signers...
# 28   Mean iconicity rating standard deviation (hear...
# 29   Mean standardized iconicity rating (Z-score) (...
# 30   Number of hearing non-signers on which Iconici...
# 31   The English translation used to elicit iconici...
# 32   Mean iconicity rating from all deaf ASL signer...
# 33   Mean iconicity rating standard deviation (all ...
# 34   Mean standardized iconicity rating (Z-score) (...
# 35   Number of deaf ASL signers  on which Iconicity...
# 36   Mean iconicity rating from only deaf ASL signe...
# 37   Mean iconicity rating standard deviation (deaf...
# 38   Mean standardized iconicity rating (Z-score) (...
# 39   Number of deaf native ASL signers on which Ico...
# 40   A measure of consistency (diversity) of guesse...
# 41   Proportion of participants who guessed the cor...
# 42   Mean transparency rating from hearing non-sign...
# 43         Mean transparency rating standard deviation
# 44    Mean standardized transparency rating (Z-score)
# 45   The lexical class or a sign (Adjective, Adverb...
# 46   Whether or not handshape of the sign is the fi...
# 47   Whether or not sign includes more than one let...
# 48   Whether or not the sign is a compound. Compoun...
# 49   The number of coded multiple sequential units ...
# 50                       The sign onset (milliseconds)
# 51                      The sign offset (milliseconds)
# 52                     Duration of sign (milliseconds)
# 53               Duration of video clip (milliseconds)
# 54   The unique combination of selected fingers, fl...
# 55   Fingers that are 1) moving, otherwise 2) finge...
# 56   Aperture of the selected fingers of the domina...
# 57                Whether or not the aperture changes
# 58                      Spread of the selected fingers
# 59                   Whether or not the spread changes
# 60                               Position of the thumb
# 61   Whether or not the thumb contacts the selected...
# 62   Symmetry of the hands according to Battison's ...
# 63     Path movement of the first morpheme in the sign
# 64   Whether or not the movement (path movement, wr...
# 65   General location of the dominant hand at sign ...
# 66   Specific location of the dominant hand at sign...
# 67   Second specific location of the dominant hand ...
# 68   Whether or not the dominant contacts the major...
# 69               The handshape of the nondominant hand
# 70                     Whether or not the wrist twists
# 71   The unique combination of selected fingers, fl...
# 72   Fingers that are 1) moving, otherwise 2) finge...
# 73   Aperture of the selected fingers of the domina...
# 74   Whether or not the aperture changes  in the se...
# 75   Spread of the selected fingers in the second m...
# 76   Whether or not the spread changes in the secon...
# 77        Position of the thumb in the second morpheme
# 78   Whether or not the thumb contacts the selected...
# 79   Symmetry of the hands according to Battison's ...
# 80   Path movement of the first morpheme in the sig...
# 81   Whether or not the movement (path movement, wr...
# 82   General location of the dominant hand at sign ...
# 83   Specific location of the dominant hand at sign...
# 84   Second specific location of the dominant hand ...
# 85   Whether or not the dominant contacts the major...
# 86   The handshape of the nondominant hand in the s...
# 87   Whether or not the wrist twists in the second ...
# 88   The unique combination of selected fingers, fl...
# 89   Fingers that are 1) moving, otherwise 2) finge...
# 90   Aperture of the selected fingers of the domina...
# 91   Whether or not the aperture changes  in the th...
# 92   Spread of the selected fingers in the third mo...
# 93   Whether or not the spread changes in the third...
# 94         Position of the thumb in the third morpheme
# 95   Whether or not the thumb contacts the selected...
# 96   Symmetry of the hands according to Battison's ...
# 97   Path movement of the first morpheme in the sig...
# 98   Whether or not the movement (path movement, wr...
# 99   General location of the dominant hand at sign ...
# 100  Specific location of the dominant hand at sign...
# 101  Second specific location of the dominant hand ...
# 102  Whether or not the dominant contacts the major...
# 103  The handshape of the nondominant hand in the t...
# 104  Whether or not the wrist twists in the third m...
# 105  The unique combination of selected fingers, fl...
# 106  Fingers that are 1) moving, otherwise 2) finge...
# 107  Aperture of the selected fingers of the domina...
# 108  Whether or not the aperture changes  in the fo...
# 109  Spread of the selected fingers in the fourth m...
# 110  Whether or not the spread changes in the fourt...
# 111       Position of the thumb in the fourth morpheme
# 112  Whether or not the thumb contacts the selected...
# 113  Symmetry of the hands according to Battison's ...
# 114  Path movement of the first morpheme in the sig...
# 115  Whether or not the movement (path movement, wr...
# 116  General location of the dominant hand at sign ...
# 117  Specific location of the dominant hand at sign...
# 118  Second specific location of the dominant hand ...
# 119  Whether or not the dominant contacts the major...
# 120  The handshape of the nondominant hand in the f...
# 121  Whether or not the wrist twists in the fourth ...
# 122  The unique combination of selected fingers, fl...
# 123  Fingers that are 1) moving, otherwise 2) finge...
# 124  Aperture of the selected fingers of the domina...
# 125  Whether or not the aperture changes  in the fi...
# 126  Spread of the selected fingers in the fifth mo...
# 127  Whether or not the spread changes in the fifth...
# 128        Position of the thumb in the fifth morpheme
# 129  Whether or not the thumb contacts the selected...
# 130  Symmetry of the hands according to Battison's ...
# 131  Path movement of the first morpheme in the sig...
# 132  Whether or not the movement (path movement, wr...
# 133  General location of the dominant hand at sign ...
# 134  Specific location of the dominant hand at sign...
# 135  Second specific location of the dominant hand ...
# 136  Whether or not the dominant contacts the major...
# 137  The handshape of the nondominant hand in the f...
# 138  Whether or not the wrist twists in the fifth m...
# 139  The unique combination of selected fingers, fl...
# 140  Fingers that are 1) moving, otherwise 2) finge...
# 141  Aperture of the selected fingers of the domina...
# 142  Whether or not the aperture changes  in the si...
# 143  Spread of the selected fingers in the sixth mo...
# 144  Whether or not the spread changes in the sixth...
# 145        Position of the thumb in the sixth morpheme
# 146  Whether or not the thumb contacts the selected...
# 147  Symmetry of the hands according to Battison's ...
# 148  Path movement of the first morpheme in the sig...
# 149  Whether or not the movement (path movement, wr...
# 150  General location of the dominant hand at sign ...
# 151  Specific location of the dominant hand at sign...
# 152  Second specific location of the dominant hand ...
# 153  Whether or not the dominant contacts the major...
# 154  The handshape of the nondominant hand in the s...
# 155  Whether or not the wrist twists in the sixth m...
# 156  Counts the frequency with which the Sign Type ...
# 157  Counts the frequency with which the Major Loca...
# 158  Counts the frequency with which the Minor Loca...
# 159  Counts the frequency with which the Second Min...
# 160  Counts the frequency with which the Movement v...
# 161  Counts the frequency with which the Selected F...
# 162  Counts the frequency with which the Flexion va...
# 163  Counts the frequency with which the Flexion Ch...
# 164  Counts the frequency with which the Repeated M...
# 165  Counts the frequency with which the Contact va...
# 166  Counts the frequency with which the Spread val...
# 167  Counts the frequency with which the Spread Cha...
# 168  Counts the frequency with which the Thumb Cont...
# 169  Counts the frequency with which the Thumb Posi...
# 170  Counts the frequency with which the Wrist Twis...
# 171  The number of neighbors that share either all ...
# 172  The number of neighbors that share either all ...
# 173   Mean of the signÕs scaled sub-lexical properties
# 174  Complexity is calculated as described in Morga...
# 175  Information from the ASL SignBank. Julie A. Ho...
# 176  Information from the ASL SignBank. Julie A. Ho...
# 177  Information from the ASL SignBank. Julie A. Ho...
# 178  Information from the ASL SignBank. Julie A. Ho...
# 179  Information from the ASL SignBank. Julie A. Ho...
# 180             Item appears in MacArthur CDI for ASL
# 181         Semantic category in MacArthur CDI for ASL
# 182  The age (in months) at which a sign is expecte...
# 183  The age (in months) at which a sign is expecte...
#
#                       KnackVariableName
# 0                               EntryID
# 1                               LemmaID
# 2                                  Code
# 3                                 Batch
# 4                                  List
# 5                                  Item
# 6                      SubtLexUSLog10WF
# 7                      SignFrequency(M)
# 8                     SignFrequency(SD)
# 9                      SignFrequency(Z)
# 10                     SignFrequency(N)
# 11                       PercentUnknown
# 12              SignFrequency(M-Native)
# 13             SignFrequency(SD-Native)
# 14                   SignFreq(Z-native)
# 15              SignFrequency(N-Native)
# 16               PercentUnknown(Native)
# 17           SignFrequency(M-Nonnative)
# 18          SignFrequency(SD-Nonnative)
# 19           SignFrequency(N-Nonnative)
# 20                SignFreq(Z-Nonnative)
# 21            PercentUnknown(Nonnative)
# 22                  DominantTranslation
# 23                PercentGlossAgreement
# 24        PercentGlossAgreement(Native)
# 25     PercentGlossAgreement(Nonnative)
# 26               NondominantTranslation
# 27                         Iconicity(M)
# 28                        Iconicity(SD)
# 29                         Iconicity(Z)
# 30                         Iconicity(N)
# 31                         Iconicity_ID
# 32                   D.Iconicity(M) all
# 33                  D.Iconicity(SD) all
# 34                   D.Iconicity(N) all
# 35                   D.Iconicity(Z) all
# 36                D.Iconicity(M) native
# 37               D.Iconicity(SD) native
# 38                D.Iconicity(Z) native
# 39                D.Iconicity(N) native
# 40                          H statistic
# 41                        GuessAccuracy
# 42                      Transparency(M)
# 43                      Transparency SD
# 44                       Transparency Z
# 45                         LexicalClass
# 46                      Initialized.2.0
# 47            FingerspelledLoanSign.2.0
# 48                         Compound.2.0
# 49                NumberOfMorphemes.2.0
# 50                        SignOnset(ms)
# 51                       SignOffset(ms)
# 52                     SignDuration(ms)
# 53                     ClipDuration(ms)
# 54                        Handshape.2.0
# 55                  SelectedFingers.2.0
# 56                          Flexion.2.0
# 57                    FlexionChange.2.0
# 58                           Spread.2.0
# 59                     SpreadChange.2.0
# 60                    ThumbPosition.2.0
# 61                     ThumbContact.2.0
# 62                         SignType.2.0
# 63                         Movement.2.0
# 64                 RepeatedMovement.2.0
# 65                    MajorLocation.2.0
# 66                    MinorLocation.2.0
# 67              SecondMinorLocation.2.0
# 68                          Contact.2.0
# 69             NonDominantHandshape.2.0
# 70                    UlnarRotation.2.0
# 71                      HandshapeM2.2.0
# 72                SelectedFingersM2.2.0
# 73                        FlexionM2.2.0
# 74                  FlexionChangeM2.2.0
# 75                         SpreadM2.2.0
# 76                   SpreadChangeM2.2.0
# 77                  ThumbPositionM2.2.0
# 78                   ThumbContactM2.2.0
# 79                       SignTypeM2.2.0
# 80                       MovementM2.2.0
# 81               RepeatedMovementM2.2.0
# 82                  MajorLocationM2.2.0
# 83                  MinorLocationM2.2.0
# 84            SecondMinorLocationM2.2.0
# 85                        ContactM2.2.0
# 86           NonDominantHandshapeM2.2.0
# 87                  UlnarRotationM2.2.0
# 88                      HandshapeM3.2.0
# 89                SelectedFingersM3.2.0
# 90                        FlexionM3.2.0
# 91                  FlexionChangeM3.2.0
# 92                         SpreadM3.2.0
# 93                   SpreadChangeM3.2.0
# 94                  ThumbPositionM3.2.0
# 95                   ThumbContactM3.2.0
# 96                       SignTypeM3.2.0
# 97                       MovementM3.2.0
# 98               RepeatedMovementM3.2.0
# 99                  MajorLocationM3.2.0
# 100                 MinorLocationM3.2.0
# 101           SecondMinorLocationM3.2.0
# 102                       ContactM3.2.0
# 103          NonDominantHandshapeM3.2.0
# 104                 UlnarRotationM3.2.0
# 105                     HandshapeM4.2.0
# 106               SelectedFingersM4.2.0
# 107                       FlexionM4.2.0
# 108                 FlexionChangeM4.2.0
# 109                        SpreadM4.2.0
# 110                  SpreadChangeM4.2.0
# 111                 ThumbPositionM4.2.0
# 112                  ThumbContactM4.2.0
# 113                      SignTypeM4.2.0
# 114                      MovementM4.2.0
# 115              RepeatedMovementM4.2.0
# 116                 MajorLocationM4.2.0
# 117                 MinorLocationM4.2.0
# 118           SecondMinorLocationM4.2.0
# 119                       ContactM4.2.0
# 120          NonDominantHandshapeM4.2.0
# 121                 UlnarRotationM4.2.0
# 122                     HandshapeM5.2.0
# 123               SelectedFingersM5.2.0
# 124                       FlexionM5.2.0
# 125                 FlexionChangeM5.2.0
# 126                        SpreadM5.2.0
# 127                  SpreadChangeM5.2.0
# 128                 ThumbPositionM5.2.0
# 129                  ThumbContactM5.2.0
# 130                      SignTypeM5.2.0
# 131                      MovementM5.2.0
# 132              RepeatedMovementM5.2.0
# 133                 MajorLocationM5.2.0
# 134                 MinorLocationM5.2.0
# 135           SecondMinorLocationM5.2.0
# 136                       ContactM5.2.0
# 137          NonDominantHandshapeM5.2.0
# 138                 UlnarRotationM5.2.0
# 139                     HandshapeM6.2.0
# 140               SelectedFingersM6.2.0
# 141                       FlexionM6.2.0
# 142                 FlexionChangeM6.2.0
# 143                        SpreadM6.2.0
# 144                  SpreadChangeM6.2.0
# 145                 ThumbPositionM6.2.0
# 146                  ThumbContactM6.2.0
# 147                      SignTypeM6.2.0
# 148                      MovementM6.2.0
# 149              RepeatedMovementM6.2.0
# 150                 MajorLocationM6.2.0
# 151                 MinorLocationM6.2.0
# 152           SecondMinorLocationM6.2.0
# 153                       ContactM6.2.0
# 154          NonDominantHandshapeM6.2.0
# 155                 UlnarRotationM6.2.0
# 156               SignType.2.0Frequency
# 157          MajorLocation.2.0Frequency
# 158          MinorLocation.2.0Frequency
# 159    SecondMinorLocation.2.0Frequency
# 160               Movement.2.0Frequency
# 161        SelectedFingers.2.0Frequency
# 162                Flexion.2.0Frequency
# 163          FlexionChange.2.0Frequency
# 164       RepeatedMovement.2.0Frequency
# 165                Contact.2.0Frequency
# 166                 Spread.2.0Frequency
# 167           SpreadChange.2.0Frequency
# 168           ThumbContact.2.0Frequency
# 169          ThumbPosition.2.0Frequency
# 170          UlnarRotation.2.0Frequency
# 171            Neighborhood Density 2.0
# 172  Parameter.Neighborhood.Density.2.0
# 173              PhonotacticProbability
# 174             Phonological Complexity
# 175                SignBankAnnotationID
# 176         SignBankEnglishTranslations
# 177                     SignBankLemmaID
# 178               SignBankSemanticField
# 179                 SignBankReferenceID
# 180                               InCDI
# 181               CDI Semantic Category
# 182                            bglm_aoa
# 183                       empirical_aoa

# %%
p = pd.read_csv("signdata.csv",encoding='ISO-8859-1')
phttps://docs.google.com/spreadsheets/d/1Md15oi74S7A2z4d9FWl26bOaYi65GgwQOru6nBzC1eA/edit#gid=1884851278jj['Stream'].isin(options)
# Out:
#          EntryID     LemmaID      Code Batch  List  Item  EnglishWF(lg10)  \
# 0           tree        tree  A_01_002     A     1     2            3.521
# 1          night       night  A_01_003     A     1     3            4.645
# 2      hamburger   hamburger  A_01_004     A     1     4            2.600
# 3         nephew      nephew  A_01_005     A     1     5            2.928
# 4         castle      castle  A_01_008     A     1     8            3.041
# ...          ...         ...       ...   ...   ...   ...              ...
# 2718     vampire     vampire  K_03_123     K     3   123            2.952
# 2719   blackbird   blackbird  K_03_124     K     3   124            1.633
# 2720      braids      braids  K_03_125     K     3   125            1.613
# 2721   stretch_2   stretch_2  K_03_126     K     3   126              NaN
# 2722  a-line_bob  a-line_bob  K_03_127     K     3   127              NaN
#
#       SignFrequency(M)  SignFrequency(SD)  SignFrequency(Z)  SignFrequency(N)  \
# 0                5.143              2.081             0.621                21
# 1                6.032              1.516             1.068                31
# 2                4.429              1.720             0.232                21
# 3                2.621              1.720            -0.753                29
# 4                1.579              0.838            -1.198                19
# ...                ...                ...               ...               ...
# 2718             4.480              2.365             0.176                25
# 2719             4.840              2.055             0.356                25
# 2720             3.480              2.163            -0.385                25
# 2721             2.708              1.654            -0.775                25
# 2722             4.273              1.804             0.030                25
#
#       Unknown  SignFrequency(M-Native)  SignFrequency(SD-Native)  \
# 0       0.000                    5.167                     2.167
# 1       0.000                    6.111                     1.568
# 2       0.000                    4.167                     1.899
# 3       0.065                    2.000                     1.317
# 4       0.095                    1.455                     0.688
# ...       ...                      ...                       ...
# 2718    0.000                    3.909                     2.386
# 2719    0.000                    4.455                     2.296
# 2720    0.000                    2.727                     1.489
# 2721    0.040                    2.400                     1.506
# 2722    0.120                    4.500                     1.069
#
#       SignFreq(Z-native)  SignFrequency(N-Native)  Unknown(Native)  \
# 0                  0.696                       12            0.000
# 1                  1.124                       18            0.000
# 2                  0.150                       12            0.000
# 3                 -1.043                       16            0.111
# 4                 -1.253                       11            0.083
# ...                  ...                      ...              ...
# 2718               0.023                       11            0.000
# 2719               0.306                       11            0.000
# 2720              -0.612                       11            0.000
# 2721              -0.695                       11            0.091
# 2722               0.349                       11            0.273
#
#       SignFrequency(M-Nonnative)  SignFrequency(SD-Nonnative)  \
# 0                          5.250                        1.585
# 1                          5.923                        1.498
# 2                          4.650                        1.531
# 3                          3.385                        1.895
# 4                          1.895                        1.487
# ...                          ...                          ...
# 2718                       4.929                        2.336
# 2719                       5.143                        1.875
# 2720                       4.071                        2.464
# 2721                       2.929                        1.774
# 2722                       4.143                        2.143
#
#       SignFrequency(N-Nonnative)  SignFreq(Z-Nonnative)  Unknown(Nonnative)  \
# 0                             20                  0.551                0.00
# 1                             13                  0.989                0.00
# 2                             20                  0.321                0.00
# 3                             13                 -0.397                0.00
# 4                             20                 -1.140                0.05
# ...                          ...                    ...                 ...
# 2718                          14                  0.297                0.00
# 2719                          14                  0.395                0.00
# 2720                          14                 -0.206                0.00
# 2721                          14                 -0.832                0.00
# 2722                          14                 -0.152                0.00
#
#      DominantTranslation  DominantTranslationAgreement  \
# 0                    NaN                         1.000
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                 nephew                         0.931
# 4                 castle                         1.000
# ...                  ...                           ...
# 2718                 NaN                           NaN
# 2719                 NaN                           NaN
# 2720                 NaN                           NaN
# 2721                 NaN                           NaN
# 2722                 NaN                           NaN
#
#       DominantTranslationAgreement(Native)  \
# 0                                    1.000
# 1                                      NaN
# 2                                      NaN
# 3                                    0.875
# 4                                    1.000
# ...                                    ...
# 2718                                   NaN
# 2719                                   NaN
# 2720                                   NaN
# 2721                                   NaN
# 2722                                   NaN
#
#       DominantTranslationAgreement(Nonnative) NondominantTranslations  \
# 0                                         1.0                     NaN
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 3                                         1.0                   niece
# 4                                         1.0                     NaN
# ...                                       ...                     ...
# 2718                                      NaN                     NaN
# 2719                                      NaN                     NaN
# 2720                                      NaN                     NaN
# 2721                                      NaN                     NaN
# 2722                                      NaN                     NaN
#
#       Iconicity(M)  Iconicity(SD)  Iconicity(Z)  Iconicity(N) Iconicity_ID  \
# 0            4.232          1.731         0.749         138.0          NaN
# 1            1.919          1.479        -0.592          37.0          NaN
# 2            3.714          1.633         0.229         140.0          NaN
# 3            1.108          0.315        -0.986          37.0          NaN
# 4            3.540          1.575         0.280         139.0          NaN
# ...            ...            ...           ...           ...          ...
# 2718         4.360          1.655         0.220          25.0      VAMPIRE
# 2719         1.760          1.091        -0.978          25.0    BLACKBIRD
# 2720         3.615          1.577        -0.099          26.0       BRAIDS
# 2721         4.400          1.732         0.224          25.0      STRETCH
# 2722         3.769          1.925        -0.047          26.0  BOB HAIRCUT
#
#      IconicityType  D.Iconicity(M)  D.Iconicity(SD)  D.Iconicity(N)  \
# 0       Perceptual            6.32             1.14            31.0
# 1        Arbitrary            2.19             1.30            31.0
# 2        Arbitrary            3.90             1.47            31.0
# 3        Arbitrary            1.14             0.44            31.0
# 4        Arbitrary            3.57             1.67            31.0
# ...            ...             ...              ...             ...
# 2718           NaN             NaN              NaN             NaN
# 2719           NaN             NaN              NaN             NaN
# 2720           NaN             NaN              NaN             NaN
# 2721           NaN             NaN              NaN             NaN
# 2722           NaN             NaN              NaN             NaN
#
#       D.Iconicity(Z)  D.Iconicity(M-native)  D.Iconicity(SD-native)  \
# 0               1.58                   6.58                    0.96
# 1              -0.58                   1.74                    1.05
# 2               0.30                   3.32                    1.29
# 3              -1.13                   1.11                    0.47
# 4               0.11                   3.65                    1.69
# ...              ...                    ...                     ...
# 2718             NaN                    NaN                     NaN
# 2719             NaN                    NaN                     NaN
# 2720             NaN                    NaN                     NaN
# 2721             NaN                    NaN                     NaN
# 2722             NaN                    NaN                     NaN
#
#       D.Iconicity(Z-native)  D.Iconicity(N-native)  GuessConsistency  \
# 0                      1.77                   19.0               NaN
# 1                     -0.76                   19.0               NaN
# 2                      0.05                   19.0               NaN
# 3                     -1.10                   19.0               NaN
# 4                      0.15                   19.0               NaN
# ...                     ...                    ...               ...
# 2718                    NaN                    NaN               NaN
# 2719                    NaN                    NaN               NaN
# 2720                    NaN                    NaN               NaN
# 2721                    NaN                    NaN               NaN
# 2722                    NaN                    NaN               NaN
#
#       GuessAccuracy  Transparency(M)  Transparency SD  Transparency Z  \
# 0               NaN              NaN              NaN             NaN
# 1               NaN              NaN              NaN             NaN
# 2               NaN              NaN              NaN             NaN
# 3               NaN              NaN              NaN             NaN
# 4               NaN              NaN              NaN             NaN
# ...             ...              ...              ...             ...
# 2718            NaN              NaN              NaN             NaN
# 2719            NaN              NaN              NaN             NaN
# 2720            NaN              NaN              NaN             NaN
# 2721            NaN              NaN              NaN             NaN
# 2722            NaN              NaN              NaN             NaN
#
#      LexicalClass  Initialized.2.0  FingerspelledLoanSign.2.0  Compound.2.0  \
# 0            Noun                0                          0             0
# 1            Noun                0                          0             0
# 2            Noun                0                          0             1
# 3            Noun                1                          0             0
# 4            Noun                0                          0             0
# ...           ...              ...                        ...           ...
# 2718         Noun                0                          0             0
# 2719         Noun                0                          0             1
# 2720         Noun                0                          0             0
# 2721         Verb                0                          0             0
# 2722         Noun                0                          0             0
#
#       NumberOfMorphemes.2.0  SignOnset(ms)  SignOffset(ms)  SignDuration(ms)  \
# 0                         1            300             801               501
# 1                         1            367            1368              1001
# 2                         2             67            1001               934
# 3                         1            334             801               467
# 4                         1            267            1068               801
# ...                     ...            ...             ...               ...
# 2718                      1            534            1602              1068
# 2719                      2            634            1735              1101
# 2720                      1            567            1568              1001
# 2721                      1            634            1768              1134
# 2722                      1            634            1301               667
#
#       ClipDuration(ms) Handshape.2.0  MarkedHandshape.2.0 SelectedFingers.2.0  \
# 0                 1034             5                    0                imrp
# 1                 1401        flat_b                    1                imrp
# 2                 1235             c                    0                imrp
# 3                 1368        flat_n                    1                  im
# 4                 2169      curved_v                    1                  im
# ...                ...           ...                  ...                 ...
# 2718              2169      curved_v                    1                  im
# 2719              2302        flat_1                    0                   i
# 2720              2069             r                    1                  im
# 2721              2436             c                    0                imrp
# 2722              1935        flat_b                    1                imrp
#
#      Flexion.2.0  FlexionChange.2.0  Spread.2.0  SpreadChange.2.0  \
# 0      FullyOpen                0.0         1.0               0.0
# 1           Flat                0.0         0.0               0.0
# 2         Curved                0.0         0.0               0.0
# 3           Flat                0.0         0.0               0.0
# 4         Curved                1.0         1.0               0.0
# ...          ...                ...         ...               ...
# 2718      Curved                0.0         1.0               0.0
# 2719        Flat                0.0         NaN               NaN
# 2720     Crossed                0.0         0.0               0.0
# 2721      Curved                1.0         0.0               0.0
# 2722        Flat                0.0         0.0               0.0
#
#      ThumbPosition.2.0  ThumbContact.2.0               SignType.2.0  \
# 0                 Open               0.0                  OneHanded
# 1                 Open               0.0  AsymmetricalSameHandshape
# 2                 Open               0.0   SymmetricalOrAlternating
# 3               Closed               1.0                  OneHanded
# 4               Closed               0.0   SymmetricalOrAlternating
# ...                ...               ...                        ...
# 2718            Closed               0.0                  OneHanded
# 2719            Closed               0.0                  OneHanded
# 2720            Closed               0.0   SymmetricalOrAlternating
# 2721              Open               0.0   SymmetricalOrAlternating
# 2722              Open               0.0   SymmetricalOrAlternating
#
#      Movement.2.0  RepeatedMovement.2.0 MajorLocation.2.0 MinorLocation.2.0  \
# 0            None                     1           Neutral           Neutral
# 1        Straight                     1              Hand          PalmBack
# 2        Straight                     0           Neutral           Neutral
# 3            None                     1              Head          HeadAway
# 4        Straight                     1           Neutral           Neutral
# ...           ...                   ...               ...               ...
# 2718     Straight                     1              Body              Neck
# 2719     Straight                     0              Head          Forehead
# 2720     Straight                     0              Head             Other
# 2721     Straight                     0           Neutral           Neutral
# 2722       Curved                     0              Head          HeadAway
#
#      SecondMinorLocation.2.0  Contact.2.0 NonDominantHandshape.2.0  \
# 0                        NaN            0                      NaN
# 1                        NaN            1                   flat_b
# 2                    Neutral            1                        c
# 3                        NaN            0                      NaN
# 4                    Neutral            1                 curved_v
# ...                      ...          ...                      ...
# 2718                     NaN            1                      NaN
# 2719                HeadAway            1                      NaN
# 2720                HeadAway            1                        r
# 2721                 Neutral            1                        c
# 2722                HeadAway            0                   flat_b
#
#       UlnarRotation.2.0 HandshapeM2.2.0  MarkedHandshapeM2.2.0  \
# 0                     1             NaN                    NaN
# 1                     0             NaN                    NaN
# 2                     0               o                    0.0
# 3                     1             NaN                    NaN
# 4                     0             NaN                    NaN
# ...                 ...             ...                    ...
# 2718                  0             NaN                    NaN
# 2719                  1               g                    0.0
# 2720                  1             NaN                    NaN
# 2721                  0             NaN                    NaN
# 2722                  1             NaN                    NaN
#
#      SelectedFingersM2.2.0 FlexionM2.2.0  FlexionChangeM2.2.0  SpreadM2.2.0  \
# 0                      NaN           NaN                  NaN           NaN
# 1                      NaN           NaN                  NaN           NaN
# 2                     imrp        Curved                  0.0           0.0
# 3                      NaN           NaN                  NaN           NaN
# 4                      NaN           NaN                  NaN           NaN
# ...                    ...           ...                  ...           ...
# 2718                   NaN           NaN                  NaN           NaN
# 2719                     i          Flat                  1.0           NaN
# 2720                   NaN           NaN                  NaN           NaN
# 2721                   NaN           NaN                  NaN           NaN
# 2722                   NaN           NaN                  NaN           NaN
#
#       SpreadChangeM2.2.0 ThumbPositionM2.2.0  ThumbContactM2.2.0  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    0.0                Open                 1.0
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 2718                 NaN                 NaN                 NaN
# 2719                 NaN                Open                 1.0
# 2720                 NaN                 NaN                 NaN
# 2721                 NaN                 NaN                 NaN
# 2722                 NaN                 NaN                 NaN
#
#                 SignTypeM2.2.0 MovementM2.2.0  RepeatedMovementM2.2.0  \
# 0                          NaN            NaN                     NaN
# 1                          NaN            NaN                     NaN
# 2     SymmetricalOrAlternating       Straight                     NaN
# 3                          NaN            NaN                     NaN
# 4                          NaN            NaN                     NaN
# ...                        ...            ...                     ...
# 2718                       NaN            NaN                     NaN
# 2719                 OneHanded           None                     1.0
# 2720                       NaN            NaN                     NaN
# 2721                       NaN            NaN                     NaN
# 2722                       NaN            NaN                     NaN
#
#      MajorLocationM2.2.0 MinorLocationM2.2.0 SecondMinorLocationM2.2.0  \
# 0                    NaN                 NaN                       NaN
# 1                    NaN                 NaN                       NaN
# 2                Neutral             Neutral                   Neutral
# 3                    NaN                 NaN                       NaN
# 4                    NaN                 NaN                       NaN
# ...                  ...                 ...                       ...
# 2718                 NaN                 NaN                       NaN
# 2719                Head               Mouth                       NaN
# 2720                 NaN                 NaN                       NaN
# 2721                 NaN                 NaN                       NaN
# 2722                 NaN                 NaN                       NaN
#
#       ContactM2.2.0 NonDominantHandshapeM2.2.0  UlnarRotationM2.2.0  \
# 0               NaN                        NaN                  NaN
# 1               NaN                        NaN                  NaN
# 2               1.0                          o                  0.0
# 3               NaN                        NaN                  NaN
# 4               NaN                        NaN                  NaN
# ...             ...                        ...                  ...
# 2718            NaN                        NaN                  NaN
# 2719            1.0                        NaN                  0.0
# 2720            NaN                        NaN                  NaN
# 2721            NaN                        NaN                  NaN
# 2722            NaN                        NaN                  NaN
#
#      HandshapeM3.2.0  MarkedHandshapeM3.2.0 SelectedFingersM3.2.0  \
# 0                NaN                    NaN                   NaN
# 1                NaN                    NaN                   NaN
# 2                NaN                    NaN                   NaN
# 3                NaN                    NaN                   NaN
# 4                NaN                    NaN                   NaN
# ...              ...                    ...                   ...
# 2718             NaN                    NaN                   NaN
# 2719             NaN                    NaN                   NaN
# 2720             NaN                    NaN                   NaN
# 2721             NaN                    NaN                   NaN
# 2722             NaN                    NaN                   NaN
#
#      FlexionM3.2.0  FlexionChangeM3.2.0  SpreadM3.2.0  SpreadChangeM3.2.0  \
# 0              NaN                  NaN           NaN                 NaN
# 1              NaN                  NaN           NaN                 NaN
# 2              NaN                  NaN           NaN                 NaN
# 3              NaN                  NaN           NaN                 NaN
# 4              NaN                  NaN           NaN                 NaN
# ...            ...                  ...           ...                 ...
# 2718           NaN                  NaN           NaN                 NaN
# 2719           NaN                  NaN           NaN                 NaN
# 2720           NaN                  NaN           NaN                 NaN
# 2721           NaN                  NaN           NaN                 NaN
# 2722           NaN                  NaN           NaN                 NaN
#
#      ThumbPositionM3.2.0  ThumbContactM3.2.0 SignTypeM3.2.0 MovementM3.2.0  \
# 0                    NaN                 NaN            NaN            NaN
# 1                    NaN                 NaN            NaN            NaN
# 2                    NaN                 NaN            NaN            NaN
# 3                    NaN                 NaN            NaN            NaN
# 4                    NaN                 NaN            NaN            NaN
# ...                  ...                 ...            ...            ...
# 2718                 NaN                 NaN            NaN            NaN
# 2719                 NaN                 NaN            NaN            NaN
# 2720                 NaN                 NaN            NaN            NaN
# 2721                 NaN                 NaN            NaN            NaN
# 2722                 NaN                 NaN            NaN            NaN
#
#       RepeatedMovementM3.2.0 MajorLocationM3.2.0 MinorLocationM3.2.0  \
# 0                        NaN                 NaN                 NaN
# 1                        NaN                 NaN                 NaN
# 2                        NaN                 NaN                 NaN
# 3                        NaN                 NaN                 NaN
# 4                        NaN                 NaN                 NaN
# ...                      ...                 ...                 ...
# 2718                     NaN                 NaN                 NaN
# 2719                     NaN                 NaN                 NaN
# 2720                     NaN                 NaN                 NaN
# 2721                     NaN                 NaN                 NaN
# 2722                     NaN                 NaN                 NaN
#
#      SecondMinorLocationM3.2.0  ContactM3.2.0 NonDominantHandshapeM3.2.0  \
# 0                          NaN            NaN                        NaN
# 1                          NaN            NaN                        NaN
# 2                          NaN            NaN                        NaN
# 3                          NaN            NaN                        NaN
# 4                          NaN            NaN                        NaN
# ...                        ...            ...                        ...
# 2718                       NaN            NaN                        NaN
# 2719                       NaN            NaN                        NaN
# 2720                       NaN            NaN                        NaN
# 2721                       NaN            NaN                        NaN
# 2722                       NaN            NaN                        NaN
#
#       UlnarRotationM3.2.0 HandshapeM4.2.0  MarkedHandshapeM4.2.0  \
# 0                     NaN             NaN                    NaN
# 1                     NaN             NaN                    NaN
# 2                     NaN             NaN                    NaN
# 3                     NaN             NaN                    NaN
# 4                     NaN             NaN                    NaN
# ...                   ...             ...                    ...
# 2718                  NaN             NaN                    NaN
# 2719                  NaN             NaN                    NaN
# 2720                  NaN             NaN                    NaN
# 2721                  NaN             NaN                    NaN
# 2722                  NaN             NaN                    NaN
#
#      SelectedFingersM4.2.0 FlexionM4.2.0  FlexionChangeM4.2.0  SpreadM4.2.0  \
# 0                      NaN           NaN                  NaN           NaN
# 1                      NaN           NaN                  NaN           NaN
# 2                      NaN           NaN                  NaN           NaN
# 3                      NaN           NaN                  NaN           NaN
# 4                      NaN           NaN                  NaN           NaN
# ...                    ...           ...                  ...           ...
# 2718                   NaN           NaN                  NaN           NaN
# 2719                   NaN           NaN                  NaN           NaN
# 2720                   NaN           NaN                  NaN           NaN
# 2721                   NaN           NaN                  NaN           NaN
# 2722                   NaN           NaN                  NaN           NaN
#
#       SpreadChangeM4.2.0 ThumbPositionM4.2.0  ThumbContactM4.2.0  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 2718                 NaN                 NaN                 NaN
# 2719                 NaN                 NaN                 NaN
# 2720                 NaN                 NaN                 NaN
# 2721                 NaN                 NaN                 NaN
# 2722                 NaN                 NaN                 NaN
#
#      SignTypeM4.2.0 MovementM4.2.0  RepeatedMovementM4.2.0  \
# 0               NaN            NaN                     NaN
# 1               NaN            NaN                     NaN
# 2               NaN            NaN                     NaN
# 3               NaN            NaN                     NaN
# 4               NaN            NaN                     NaN
# ...             ...            ...                     ...
# 2718            NaN            NaN                     NaN
# 2719            NaN            NaN                     NaN
# 2720            NaN            NaN                     NaN
# 2721            NaN            NaN                     NaN
# 2722            NaN            NaN                     NaN
#
#      MajorLocationM4.2.0 MinorLocationM4.2.0 SecondMinorLocationM4.2.0  \
# 0                    NaN                 NaN                       NaN
# 1                    NaN                 NaN                       NaN
# 2                    NaN                 NaN                       NaN
# 3                    NaN                 NaN                       NaN
# 4                    NaN                 NaN                       NaN
# ...                  ...                 ...                       ...
# 2718                 NaN                 NaN                       NaN
# 2719                 NaN                 NaN                       NaN
# 2720                 NaN                 NaN                       NaN
# 2721                 NaN                 NaN                       NaN
# 2722                 NaN                 NaN                       NaN
#
#       ContactM4.2.0  NonDominantHandshapeM4.2.0  UlnarRotationM4.2.0  \
# 0               NaN                         NaN                  NaN
# 1               NaN                         NaN                  NaN
# 2               NaN                         NaN                  NaN
# 3               NaN                         NaN                  NaN
# 4               NaN                         NaN                  NaN
# ...             ...                         ...                  ...
# 2718            NaN                         NaN                  NaN
# 2719            NaN                         NaN                  NaN
# 2720            NaN                         NaN                  NaN
# 2721            NaN                         NaN                  NaN
# 2722            NaN                         NaN                  NaN
#
#      HandshapeM5.2.0  MarkedHandshapeM5.2.0 SelectedFingersM5.2.0  \
# 0                NaN                    NaN                   NaN
# 1                NaN                    NaN                   NaN
# 2                NaN                    NaN                   NaN
# 3                NaN                    NaN                   NaN
# 4                NaN                    NaN                   NaN
# ...              ...                    ...                   ...
# 2718             NaN                    NaN                   NaN
# 2719             NaN                    NaN                   NaN
# 2720             NaN                    NaN                   NaN
# 2721             NaN                    NaN                   NaN
# 2722             NaN                    NaN                   NaN
#
#      FlexionM5.2.0  FlexionChangeM5.2.0  SpreadM5.2.0  SpreadChangeM5.2.0  \
# 0              NaN                  NaN           NaN                 NaN
# 1              NaN                  NaN           NaN                 NaN
# 2              NaN                  NaN           NaN                 NaN
# 3              NaN                  NaN           NaN                 NaN
# 4              NaN                  NaN           NaN                 NaN
# ...            ...                  ...           ...                 ...
# 2718           NaN                  NaN           NaN                 NaN
# 2719           NaN                  NaN           NaN                 NaN
# 2720           NaN                  NaN           NaN                 NaN
# 2721           NaN                  NaN           NaN                 NaN
# 2722           NaN                  NaN           NaN                 NaN
#
#      ThumbPositionM5.2.0  ThumbContactM5.2.0  SignTypeM5.2.0  MovementM5.2.0  \
# 0                    NaN                 NaN             NaN             NaN
# 1                    NaN                 NaN             NaN             NaN
# 2                    NaN                 NaN             NaN             NaN
# 3                    NaN                 NaN             NaN             NaN
# 4                    NaN                 NaN             NaN             NaN
# ...                  ...                 ...             ...             ...
# 2718                 NaN                 NaN             NaN             NaN
# 2719                 NaN                 NaN             NaN             NaN
# 2720                 NaN                 NaN             NaN             NaN
# 2721                 NaN                 NaN             NaN             NaN
# 2722                 NaN                 NaN             NaN             NaN
#
#       RepeatedMovementM5.2.0  MajorLocationM5.2.0  MinorLocationM5.2.0  \
# 0                        NaN                  NaN                  NaN
# 1                        NaN                  NaN                  NaN
# 2                        NaN                  NaN                  NaN
# 3                        NaN                  NaN                  NaN
# 4                        NaN                  NaN                  NaN
# ...                      ...                  ...                  ...
# 2718                     NaN                  NaN                  NaN
# 2719                     NaN                  NaN                  NaN
# 2720                     NaN                  NaN                  NaN
# 2721                     NaN                  NaN                  NaN
# 2722                     NaN                  NaN                  NaN
#
#       SecondMinorLocationM5.2.0  ContactM5.2.0  NonDominantHandshapeM5.2.0  \
# 0                           NaN            NaN                         NaN
# 1                           NaN            NaN                         NaN
# 2                           NaN            NaN                         NaN
# 3                           NaN            NaN                         NaN
# 4                           NaN            NaN                         NaN
# ...                         ...            ...                         ...
# 2718                        NaN            NaN                         NaN
# 2719                        NaN            NaN                         NaN
# 2720                        NaN            NaN                         NaN
# 2721                        NaN            NaN                         NaN
# 2722                        NaN            NaN                         NaN
#
#       UlnarRotationM5.2.0 HandshapeM6.2.0  MarkedHandshapeM6.2.0  \
# 0                     NaN             NaN                    NaN
# 1                     NaN             NaN                    NaN
# 2                     NaN             NaN                    NaN
# 3                     NaN             NaN                    NaN
# 4                     NaN             NaN                    NaN
# ...                   ...             ...                    ...
# 2718                  NaN             NaN                    NaN
# 2719                  NaN             NaN                    NaN
# 2720                  NaN             NaN                    NaN
# 2721                  NaN             NaN                    NaN
# 2722                  NaN             NaN                    NaN
#
#      SelectedFingersM6.2.0 FlexionM6.2.0  FlexionChangeM6.2.0  SpreadM6.2.0  \
# 0                      NaN           NaN                  NaN           NaN
# 1                      NaN           NaN                  NaN           NaN
# 2                      NaN           NaN                  NaN           NaN
# 3                      NaN           NaN                  NaN           NaN
# 4                      NaN           NaN                  NaN           NaN
# ...                    ...           ...                  ...           ...
# 2718                   NaN           NaN                  NaN           NaN
# 2719                   NaN           NaN                  NaN           NaN
# 2720                   NaN           NaN                  NaN           NaN
# 2721                   NaN           NaN                  NaN           NaN
# 2722                   NaN           NaN                  NaN           NaN
#
#       SpreadChangeM6.2.0 ThumbPositionM6.2.0  ThumbContactM6.2.0  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 2718                 NaN                 NaN                 NaN
# 2719                 NaN                 NaN                 NaN
# 2720                 NaN                 NaN                 NaN
# 2721                 NaN                 NaN                 NaN
# 2722                 NaN                 NaN                 NaN
#
#       SignTypeM6.2.0  MovementM6.2.0  RepeatedMovementM6.2.0  \
# 0                NaN             NaN                     NaN
# 1                NaN             NaN                     NaN
# 2                NaN             NaN                     NaN
# 3                NaN             NaN                     NaN
# 4                NaN             NaN                     NaN
# ...              ...             ...                     ...
# 2718             NaN             NaN                     NaN
# 2719             NaN             NaN                     NaN
# 2720             NaN             NaN                     NaN
# 2721             NaN             NaN                     NaN
# 2722             NaN             NaN                     NaN
#
#       MajorLocationM6.2.0  MinorLocationM6.2.0  SecondMinorLocationM6.2.0  \
# 0                     NaN                  NaN                        NaN
# 1                     NaN                  NaN                        NaN
# 2                     NaN                  NaN                        NaN
# 3                     NaN                  NaN                        NaN
# 4                     NaN                  NaN                        NaN
# ...                   ...                  ...                        ...
# 2718                  NaN                  NaN                        NaN
# 2719                  NaN                  NaN                        NaN
# 2720                  NaN                  NaN                        NaN
# 2721                  NaN                  NaN                        NaN
# 2722                  NaN                  NaN                        NaN
#
#       ContactM6.2.0  NonDominantHandshapeM6.2.0  UlnarRotationM6.2.0  \
# 0               NaN                         NaN                  NaN
# 1               NaN                         NaN                  NaN
# 2               NaN                         NaN                  NaN
# 3               NaN                         NaN                  NaN
# 4               NaN                         NaN                  NaN
# ...             ...                         ...                  ...
# 2718            NaN                         NaN                  NaN
# 2719            NaN                         NaN                  NaN
# 2720            NaN                         NaN                  NaN
# 2721            NaN                         NaN                  NaN
# 2722            NaN                         NaN                  NaN
#
#       SignType.2.0Frequency  MajorLocation.2.0Frequency  \
# 0                     0.392                       0.363
# 1                     0.059                       0.250
# 2                     0.345                       0.363
# 3                     0.392                       0.266
# 4                     0.345                       0.363
# ...                     ...                         ...
# 2718                  0.392                       0.094
# 2719                  0.392                       0.266
# 2720                  0.345                       0.266
# 2721                  0.345                       0.363
# 2722                  0.345                       0.266
#
#       MinorLocation.2.0Frequency  SecondMinorLocation.2.0Frequency  \
# 0                          0.363                             0.000
# 1                          0.024                             0.000
# 2                          0.363                             0.426
# 3                          0.066                             0.000
# 4                          0.363                             0.426
# ...                          ...                               ...
# 2718                       0.006                             0.000
# 2719                       0.039                             0.178
# 2720                       0.025                             0.178
# 2721                       0.363                             0.426
# 2722                       0.066                             0.178
#
#       Movement.2.0Frequency  SelectedFingers.2.0Frequency  \
# 0                     0.153                         0.449
# 1                     0.457                         0.449
# 2                     0.457                         0.449
# 3                     0.153                         0.140
# 4                     0.457                         0.140
# ...                     ...                           ...
# 2718                  0.457                         0.140
# 2719                  0.457                         0.261
# 2720                  0.457                         0.140
# 2721                  0.457                         0.449
# 2722                  0.233                         0.449
#
#       Flexion.2.0Frequency  FlexionChange.2.0Frequency  \
# 0                    0.409                       0.791
# 1                    0.162                       0.791
# 2                    0.225                       0.791
# 3                    0.162                       0.791
# 4                    0.225                       0.209
# ...                    ...                         ...
# 2718                 0.225                       0.791
# 2719                 0.162                       0.791
# 2720                 0.012                       0.791
# 2721                 0.225                       0.209
# 2722                 0.162                       0.791
#
#       RepeatedMovement.2.0Frequency  Contact.2.0Frequency  \
# 0                             0.446                 0.378
# 1                             0.446                 0.622
# 2                             0.554                 0.622
# 3                             0.446                 0.378
# 4                             0.446                 0.622
# ...                             ...                   ...
# 2718                          0.446                 0.622
# 2719                          0.554                 0.622
# 2720                          0.554                 0.622
# 2721                          0.554                 0.622
# 2722                          0.554                 0.378
#
#       Spread.2.0Frequency  SpreadChange.2.0Frequency  \
# 0                   0.398                      0.878
# 1                   0.602                      0.878
# 2                   0.602                      0.878
# 3                   0.602                      0.878
# 4                   0.398                      0.878
# ...                   ...                        ...
# 2718                0.398                      0.878
# 2719                0.000                      0.000
# 2720                0.602                      0.878
# 2721                0.602                      0.878
# 2722                0.602                      0.878
#
#       ThumbContact.2.0Frequency  ThumbPosition.2.0Frequency  \
# 0                         0.684                       0.657
# 1                         0.684                       0.657
# 2                         0.684                       0.657
# 3                         0.316                       0.343
# 4                         0.684                       0.343
# ...                         ...                         ...
# 2718                      0.684                       0.343
# 2719                      0.684                       0.343
# 2720                      0.684                       0.343
# 2721                      0.684                       0.657
# 2722                      0.684                       0.657
#
#       UlnarRotation.2.0Frequency  Neighborhood Density 2.0  \
# 0                          0.164                         4
# 1                          0.836                         5
# 2                          0.836                        11
# 3                          0.164                         0
# 4                          0.836                         1
# ...                          ...                       ...
# 2718                       0.836                         0
# 2719                       0.164                         2
# 2720                       0.164                         0
# 2721                       0.836                         6
# 2722                       0.164                         4
#
#       Parameter.Neighborhood.Density.2.0  PhonotacticProbability  \
# 0                                    190                   0.147
# 1                                    391                   0.099
# 2                                    488                   0.821
# 3                                    220                  -0.505
# 4                                    453                   0.226
# ...                                  ...                     ...
# 2718                                 125                  -0.123
# 2719                                 326                  -0.169
# 2720                                 327                  -0.040
# 2721                                 488                   0.684
# 2722                                 158                   0.089
#
#       Phonological Complexity SignBankAnnotationID  \
# 0                         1.0                 TREE
# 1                         1.0                NIGHT
# 2                         2.0            HAMBURGER
# 3                         2.0               NEPHEW
# 4                         2.0               CASTLE
# ...                       ...                  ...
# 2718                      2.0              VAMPIRE
# 2719                      NaN                  NaN
# 2720                      3.0                  NaN
# 2721                      1.0                  NaN
# 2722                      2.0                  NaN
#
#                   SignBankEnglishTranslations SignBankLemmaID  \
# 0          forest, nature, plant, tree, woods            TREE
# 1                              night, evening           NIGHT
# 2                 burger, hamburger, sandwich       HAMBURGER
# 3                                      nephew          NEPHEW
# 4                              castle, palace          CASTLE
# ...                                       ...             ...
# 2718  bat, fanged, mythical creature, vampire         VAMPIRE
# 2719                                      NaN             NaN
# 2720                                      NaN             NaN
# 2721                                      NaN             NaN
# 2722                                      NaN             NaN
#
#      SignBankSemanticField  SignBankReferenceID InCDI  \
# 0                     None                342.0   Yes
# 1                     None                199.0   Yes
# 2                     None               1844.0   Yes
# 3                   People               3011.0    No
# 4                     None               2471.0    No
# ...                    ...                  ...   ...
# 2718                  None               1371.0    No
# 2719                   NaN                  NaN    No
# 2720                   NaN                  NaN    No
# 2721                   NaN                  NaN    No
# 2722                   NaN                  NaN    No
#
#                   CDISemanticCategory  bglm_aoa  empirical_aoa
# 0     Outside Things and Places to Go      22.0           14.0
# 1                    Signs About Time      31.0           18.0
# 2                      Food and Drink      32.0           28.0
# 3                                 NaN       NaN            NaN
# 4                        Action Signs       NaN            NaN
# ...                               ...       ...            ...
# 2718                              NaN       NaN            NaN
# 2719                              NaN       NaN            NaN
# 2720                              NaN       NaN            NaN
# 2721                              NaN       NaN            NaN
# 2722                              NaN       NaN            NaN
#
# [2723 rows x 191 columns]

# %%
test = p.loc[p["EntryID"] == "bar"]
test
# Out:
#     EntryID LemmaID      Code Batch  List  Item  EnglishWF(lg10)  \
# 224     bar     bar  A_03_072     A     3    72            3.642
#
#      SignFrequency(M)  SignFrequency(SD)  SignFrequency(Z)  SignFrequency(N)  \
# 224             4.087              1.881             0.017                23
#
#      Unknown  SignFrequency(M-Native)  SignFrequency(SD-Native)  \
# 224     0.08                    3.923                     2.019
#
#      SignFreq(Z-native)  SignFrequency(N-Native)  Unknown(Native)  \
# 224              -0.011                       13            0.133
#
#      SignFrequency(M-Nonnative)  SignFrequency(SD-Nonnative)  \
# 224                         4.3                        1.767
#
#      SignFrequency(N-Nonnative)  SignFreq(Z-Nonnative)  Unknown(Nonnative)  \
# 224                          10                  0.053                 0.0
#
#     DominantTranslation  DominantTranslationAgreement  \
# 224                 NaN                           NaN
#
#      DominantTranslationAgreement(Native)  \
# 224                                   NaN
#
#      DominantTranslationAgreement(Nonnative) NondominantTranslations  \
# 224                                      NaN                     NaN
#
#      Iconicity(M)  Iconicity(SD)  Iconicity(Z)  Iconicity(N) Iconicity_ID  \
# 224          2.19          1.601        -0.624          21.0          NaN
#
#     IconicityType  D.Iconicity(M)  D.Iconicity(SD)  D.Iconicity(N)  \
# 224     Arbitrary            3.18             1.91            31.0
#
#      D.Iconicity(Z)  D.Iconicity(M-native)  D.Iconicity(SD-native)  \
# 224           -0.05                   3.47                    2.18
#
#      D.Iconicity(Z-native)  D.Iconicity(N-native)  GuessConsistency  \
# 224                   0.14                   19.0               NaN
#
#      GuessAccuracy  Transparency(M)  Transparency SD  Transparency Z  \
# 224            NaN              NaN              NaN             NaN
#
#     LexicalClass  Initialized.2.0  FingerspelledLoanSign.2.0  Compound.2.0  \
# 224         Noun                0                          0             0
#
#      NumberOfMorphemes.2.0  SignOnset(ms)  SignOffset(ms)  SignDuration(ms)  \
# 224                      1            300            2002              1702
#
#      ClipDuration(ms) Handshape.2.0  MarkedHandshape.2.0 SelectedFingers.2.0  \
# 224              3136             a                    0                   t
#
#     Flexion.2.0  FlexionChange.2.0  Spread.2.0  SpreadChange.2.0  \
# 224         NaN                NaN         NaN               NaN
#
#     ThumbPosition.2.0  ThumbContact.2.0 SignType.2.0 Movement.2.0  \
# 224              Open               NaN    OneHanded     Straight
#
#      RepeatedMovement.2.0 MajorLocation.2.0 MinorLocation.2.0  \
# 224                     1              Head             Mouth
#
#     SecondMinorLocation.2.0  Contact.2.0 NonDominantHandshape.2.0  \
# 224                     NaN            0                      NaN
#
#      UlnarRotation.2.0 HandshapeM2.2.0  MarkedHandshapeM2.2.0  \
# 224                  0             NaN                    NaN
#
#     SelectedFingersM2.2.0 FlexionM2.2.0  FlexionChangeM2.2.0  SpreadM2.2.0  \
# 224                   NaN           NaN                  NaN           NaN
#
#      SpreadChangeM2.2.0 ThumbPositionM2.2.0  ThumbContactM2.2.0  \
# 224                 NaN                 NaN                 NaN
#
#     SignTypeM2.2.0 MovementM2.2.0  RepeatedMovementM2.2.0 MajorLocationM2.2.0  \
# 224            NaN            NaN                     NaN                 NaN
#
#     MinorLocationM2.2.0 SecondMinorLocationM2.2.0  ContactM2.2.0  \
# 224                 NaN                       NaN            NaN
#
#     NonDominantHandshapeM2.2.0  UlnarRotationM2.2.0 HandshapeM3.2.0  \
# 224                        NaN                  NaN             NaN
#
#      MarkedHandshapeM3.2.0 SelectedFingersM3.2.0 FlexionM3.2.0  \
# 224                    NaN                   NaN           NaN
#
#      FlexionChangeM3.2.0  SpreadM3.2.0  SpreadChangeM3.2.0  \
# 224                  NaN           NaN                 NaN
#
#     ThumbPositionM3.2.0  ThumbContactM3.2.0 SignTypeM3.2.0 MovementM3.2.0  \
# 224                 NaN                 NaN            NaN            NaN
#
#      RepeatedMovementM3.2.0 MajorLocationM3.2.0 MinorLocationM3.2.0  \
# 224                     NaN                 NaN                 NaN
#
#     SecondMinorLocationM3.2.0  ContactM3.2.0 NonDominantHandshapeM3.2.0  \
# 224                       NaN            NaN                        NaN
#
#      UlnarRotationM3.2.0 HandshapeM4.2.0  MarkedHandshapeM4.2.0  \
# 224                  NaN             NaN                    NaN
#
#     SelectedFingersM4.2.0 FlexionM4.2.0  FlexionChangeM4.2.0  SpreadM4.2.0  \
# 224                   NaN           NaN                  NaN           NaN
#
#      SpreadChangeM4.2.0 ThumbPositionM4.2.0  ThumbContactM4.2.0  \
# 224                 NaN                 NaN                 NaN
#
#     SignTypeM4.2.0 MovementM4.2.0  RepeatedMovementM4.2.0 MajorLocationM4.2.0  \
# 224            NaN            NaN                     NaN                 NaN
#
#     MinorLocationM4.2.0 SecondMinorLocationM4.2.0  ContactM4.2.0  \
# 224                 NaN                       NaN            NaN
#
#      NonDominantHandshapeM4.2.0  UlnarRotationM4.2.0 HandshapeM5.2.0  \
# 224                         NaN                  NaN             NaN
#
#      MarkedHandshapeM5.2.0 SelectedFingersM5.2.0 FlexionM5.2.0  \
# 224                    NaN                   NaN           NaN
#
#      FlexionChangeM5.2.0  SpreadM5.2.0  SpreadChangeM5.2.0  \
# 224                  NaN           NaN                 NaN
#
#     ThumbPositionM5.2.0  ThumbContactM5.2.0  SignTypeM5.2.0  MovementM5.2.0  \
# 224                 NaN                 NaN             NaN             NaN
#
#      RepeatedMovementM5.2.0  MajorLocationM5.2.0  MinorLocationM5.2.0  \
# 224                     NaN                  NaN                  NaN
#
#      SecondMinorLocationM5.2.0  ContactM5.2.0  NonDominantHandshapeM5.2.0  \
# 224                        NaN            NaN                         NaN
#
#      UlnarRotationM5.2.0 HandshapeM6.2.0  MarkedHandshapeM6.2.0  \
# 224                  NaN             NaN                    NaN
#
#     SelectedFingersM6.2.0 FlexionM6.2.0  FlexionChangeM6.2.0  SpreadM6.2.0  \
# 224                   NaN           NaN                  NaN           NaN
#
#      SpreadChangeM6.2.0 ThumbPositionM6.2.0  ThumbContactM6.2.0  \
# 224                 NaN                 NaN                 NaN
#
#      SignTypeM6.2.0  MovementM6.2.0  RepeatedMovementM6.2.0  \
# 224             NaN             NaN                     NaN
#
#      MajorLocationM6.2.0  MinorLocationM6.2.0  SecondMinorLocationM6.2.0  \
# 224                  NaN                  NaN                        NaN
#
#      ContactM6.2.0  NonDominantHandshapeM6.2.0  UlnarRotationM6.2.0  \
# 224            NaN                         NaN                  NaN
#
#      SignType.2.0Frequency  MajorLocation.2.0Frequency  \
# 224                  0.392                       0.266
#
#      MinorLocation.2.0Frequency  SecondMinorLocation.2.0Frequency  \
# 224                       0.046                               0.0
#
#      Movement.2.0Frequency  SelectedFingers.2.0Frequency  \
# 224                  0.457                         0.057
#
#      Flexion.2.0Frequency  FlexionChange.2.0Frequency  \
# 224                   0.0                         0.0
#
#      RepeatedMovement.2.0Frequency  Contact.2.0Frequency  Spread.2.0Frequency  \
# 224                          0.446                 0.378                  0.0
#
#      SpreadChange.2.0Frequency  ThumbContact.2.0Frequency  \
# 224                        0.0                        0.0
#
#      ThumbPosition.2.0Frequency  UlnarRotation.2.0Frequency  \
# 224                       0.657                       0.836
#
#      Neighborhood Density 2.0  Parameter.Neighborhood.Density.2.0  \
# 224                         5                                 396
#
#      PhonotacticProbability  Phonological Complexity SignBankAnnotationID  \
# 224                  -0.747                      2.0                  BAR
#
#          SignBankEnglishTranslations SignBankLemmaID SignBankSemanticField  \
# 224  alcohol, bar, booze, drink, pub             BAR                  None
#
#      SignBankReferenceID InCDI CDISemanticCategory  bglm_aoa  empirical_aoa
# 224               2203.0    No                 NaN       NaN            NaN

# %%
fingers = test["SelectedFingers.2.0"]

# %%
from selenium import webdriver
driver = webdriver.Firefox()

# %%
driver.get("http://aslfont.github.io/sign-puppet/demo/#forward")

# %%
driver.execute_script("""
var animator = puppet.getAnimator();
//set up animation loop (in production use a requestAnimationFrame shim)
setInterval(
  function () {
    canvas.getContext('2d').clearRect(0, 0, canvas.width, canvas.height);
    animator.tween();
    //if omitted, 'channels' defaults to the animator object's channels
    puppet.draw(canvas, canvas.width, canvas.height, 0, 0);
  },
  100 // 10 frames per second
);
""")

# %%
from movement import move, hand_movement

# %%
driver.execute_script(move.move_character(hand_movement.close_thumb(), 1500))

# %%
hand_movement.close_thumb()
# Out:
# {'rt0x': 1, 'rt0y': 1, 'rt1x': 1, 'rt1y': 1, 'rt2x': 1}
